# %% [markdown]
# # Import Library

# %%
import cv2
from PIL import Image
import datetime
import numpy as np
import tensorflow as tf
keras = tf.keras
import matplotlib.pyplot as plt

# %% [markdown]
# # Defining Functions

# %%
def processImage(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image,channels=3)
    image = tf.image.convert_image_dtype(image,tf.float32)
    image = tf.image.resize(image,size=[224,224])
    return image

# %%
def batch_data(image):
    data = tf.data.Dataset.from_tensor_slices((image))
    batch = data.map(processImage).batch(32)
    return batch

# %%
import os
os.chdir('drive/My Drive/PythonProject/Face Mask Detection')

# %% [markdown]
# # Loading NN Model

# %%
model = keras.models.load_model('face_mask_ai.h5')
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_18 (Conv2D)           (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 86528)             0
# ...

# %% [markdown]
# # Video Capture from Files

# %%
prediction = model.predict(batch_data(['test/budis2.jpg']))

# %%
prediction,prediction.shape
# Out:
# (array([[0.23113933, 0.76886064]], dtype=float32), (1, 2))
